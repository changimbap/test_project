# %%
# 간단 배포
# !pip install pyinstaller
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.4 MB 479.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 275.1 kB/s eta 0:00:03
# ...

# %%
# !pyinstaller --onefile day11.py
# Out:
# 24 DEPRECATION: Running PyInstaller as admin is not necessary nor sensible. Run PyInstaller from a non-administrator terminal. PyInstaller 7.0 will block this.
# 228 INFO: PyInstaller: 6.14.2, contrib hooks: 2025.5
# 228 INFO: Python: 3.9.23 (conda)
# 234 INFO: Platform: Windows-10-10.0.26100-SP0
# 234 INFO: Python environment: C:\ProgramData\anaconda3\envs\myenv
# 234 INFO: wrote C:\Users\kccistc\Desktop\workspace\day11.spec
# 244 INFO: Module search paths (PYTHONPATH):
# ['C:\\ProgramData\\anaconda3\\envs\\myenv\\Scripts\\pyinstaller.exe',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\python39.zip',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\DLLs',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\anaconda3\\envs\\myenv\\lib\\site-packages\\win32\\lib',
# ...
